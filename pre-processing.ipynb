# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('./2015.csv')

# %%
a = []
for i in range(158):
    a.append(2015)
df1['Year']=a

# %%
df1.rename(columns = {'Economy (GDP per Capita)' : 'GDP',
                        'Health (Life Expectancy)' : 'Life',
                        'Trust (Government Corruption)' : 'Trust'}, inplace = True)
df1=df1.drop(columns=['Standard Error','Dystopia Residual'])

# %%
df2 = pd.read_csv('./2016.csv')

# %%
b = []
for i in range(157):
    b.append(2016)
df2['Year']=b

# %%
df2.rename(columns = {'Economy (GDP per Capita)' : 'GDP',
                        'Health (Life Expectancy)' : 'Life',
                        'Trust (Government Corruption)' : 'Trust'}, inplace = True)

# %%
df2=df2.drop(columns=['Lower Confidence Interval','Upper Confidence Interval','Dystopia Residual'])

# %%
df3 = pd.read_csv('./2017.csv')

# %%
c = []
for i in range(155):
    c.append(2017)
df3['Year']=c

# %%
df3.rename(columns = {'Happiness.Rank' : 'Happiness Rank',
                        'Happiness.Score' : 'Happiness Score',
                        'Economy..GDP.per.Capita.' : 'GDP',
                        'Health..Life.Expectancy.' : 'Life',
                        'Dystopia.Residual' : 'Dystopia Residual',
                        'Trust..Government.Corruption.' : 'Trust'}, inplace = True)

# %%
df3=df3.drop(columns=['Whisker.high','Whisker.low','Dystopia Residual'])

# %%
df4 = pd.read_csv('./2018.csv')

# %%
d = []
for i in range(156):
    d.append(2018)
df4['Year']=d

# %%
df4.rename(columns = {'Overall rank' : 'Happiness Rank',
                        'Score' : 'Happiness Score',
                        'Country or region' : 'Country',
                        'Social support' : 'Family',
                        'Freedom to make life choices' : 'Freedom',
                        'GDP per capita' : 'GDP',
                        'Healthy life expectancy' : 'Life',
                        'Perceptions of corruption' : 'Trust'}, inplace = True)

# %%
df5 = pd.read_csv('./2019.csv')

# %%
e = []
for i in range(156):
    e.append(2019)
df5['Year']=e

# %%
df5.rename(columns = {'Overall rank' : 'Happiness Rank',
                        'Score' : 'Happiness Score',
                        'Country or region' : 'Country',
                        'Social support' : 'Family',
                        'Freedom to make life choices' : 'Freedom',
                        'GDP per capita' : 'GDP',
                        'Healthy life expectancy' : 'Life',
                        'Perceptions of corruption' : 'Trust'}, inplace = True)

# %%
dfs=[df1,df2,df3,df4,df5]
for df in dfs:
    if not ('Region') in df:
        df['Region'] = None
        temp = df.set_index('Country').Region.fillna(df1.set_index('Country').Region).reset_index()
        df.fillna(temp, inplace = True)

# %%
df1
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score      GDP   Family     Life  Freedom    Trust  Generosity  \
# 0              7.587  1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# ...

# %%
df2
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score      GDP   Family     Life  Freedom    Trust  Generosity  \
# 0              7.526  1.44178  1.16374  0.79504  0.57941  0.44453     0.36171
# ...

# %%
df3
# Out:
#                       Country  Happiness Rank  Happiness Score       GDP  \
# 0                      Norway               1            7.537  1.616463
# 1                     Denmark               2            7.522  1.482383
# 2                     Iceland               3            7.504  1.480633
# 3                 Switzerland               4            7.494  1.564980
# 4                     Finland               5            7.469  1.443572
# ..                        ...             ...              ...       ...
# 150                    Rwanda             151            3.471  0.368746
# 151                     Syria             152            3.462  0.777153
# 152                  Tanzania             153            3.349  0.511136
# 153                   Burundi             154            2.905  0.091623
# 154  Central African Republic             155            2.693  0.000000
#
#        Family      Life   Freedom  Generosity     Trust  Year  \
# ...

# %%
df4
# Out:
#      Happiness Rank                   Country  Happiness Score    GDP  Family  \
# 0                 1                   Finland            7.632  1.305   1.592
# 1                 2                    Norway            7.594  1.456   1.582
# 2                 3                   Denmark            7.555  1.351   1.590
# 3                 4                   Iceland            7.495  1.343   1.644
# 4                 5               Switzerland            7.487  1.420   1.549
# ..              ...                       ...              ...    ...     ...
# 151             152                     Yemen            3.355  0.442   1.073
# 152             153                  Tanzania            3.303  0.455   0.991
# 153             154               South Sudan            3.254  0.337   0.608
# 154             155  Central African Republic            3.083  0.024   0.000
# 155             156                   Burundi            2.905  0.091   0.627
#
# ...

# %%
df5
# Out:
#      Happiness Rank                   Country  Happiness Score    GDP  Family  \
# 0                 1                   Finland            7.769  1.340   1.587
# 1                 2                   Denmark            7.600  1.383   1.573
# 2                 3                    Norway            7.554  1.488   1.582
# 3                 4                   Iceland            7.494  1.380   1.624
# 4                 5               Netherlands            7.488  1.396   1.522
# ..              ...                       ...              ...    ...     ...
# 151             152                    Rwanda            3.334  0.359   0.711
# 152             153                  Tanzania            3.231  0.476   0.885
# 153             154               Afghanistan            3.203  0.350   0.517
# 154             155  Central African Republic            3.083  0.026   0.000
# 155             156               South Sudan            2.853  0.306   0.575
#
# ...

# %%
dataset = pd.concat(dfs)

# %%
dataset
# Out:
#                       Country              Region  Happiness Rank  \
# 0                 Switzerland      Western Europe               1
# 1                     Iceland      Western Europe               2
# 2                     Denmark      Western Europe               3
# 3                      Norway      Western Europe               4
# 4                      Canada       North America               5
# ..                        ...                 ...             ...
# 151                    Rwanda  Sub-Saharan Africa             152
# 152                  Tanzania  Sub-Saharan Africa             153
# 153               Afghanistan       Southern Asia             154
# 154  Central African Republic  Sub-Saharan Africa             155
# 155               South Sudan                 NaN             156
#
#      Happiness Score      GDP   Family     Life  Freedom    Trust  Generosity  \
# 0              7.587  1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# ...

# %%
geo = pd.read_csv('./geo.csv')

# %%
geo
# Out:
#     country   latitude  longitude                  name
# 0        AD  42.546245   1.601554               Andorra
# 1        AE  23.424076  53.847818  United Arab Emirates
# 2        AF  33.939110  67.709953           Afghanistan
# 3        AG  17.060816 -61.796428   Antigua and Barbuda
# 4        AI  18.220554 -63.068615              Anguilla
# ..      ...        ...        ...                   ...
# 240      YE  15.552727  48.516388                 Yemen
# 241      YT -12.827500  45.166244               Mayotte
# 242      ZA -30.559482  22.937506          South Africa
# 243      ZM -13.133897  27.849332                Zambia
# 244      ZW -19.015438  29.154857              Zimbabwe
#
# [245 rows x 4 columns]

# %%
dfinal = dataset.merge(geo, how='inner', left_on='Country', right_on='name')

# %%
dfinal
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1    Switzerland      Western Europe               2            7.509
# 2    Switzerland      Western Europe               4            7.494
# 3    Switzerland      Western Europe               5            7.487
# 4    Switzerland      Western Europe               6            7.480
# ..           ...                 ...             ...              ...
# 737      Namibia  Sub-Saharan Africa             113            4.574
# 738      Namibia                 NaN             111            4.574
# 739      Namibia                 NaN             119            4.441
# 740      Namibia                 NaN             113            4.639
# 741       Gambia                 NaN             120            4.516
#
#           GDP    Family      Life   Freedom     Trust  Generosity  Year  \
# ...

# %%
for i in range(742):
    if dfinal['Country'][i]=='Belize':
        dfinal['Region'][i]=('Latin America and Caribbean')
    if dfinal['Country'][i]=='Somalia':
        dfinal['Region'][i]='Sub-Saharan Africa'
    if dfinal['Country'][i]=='Namibia':
        dfinal['Region'][i]='Sub-Saharan Africa'
        dfinal['country'][i]='SO'
    if dfinal['Country'][i]=='Gambia':
        dfinal['Region'][i]='Western Africa'
# Out:
# <ipython-input-51-67c0de7798f9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfinal['Region'][i]=('Latin America and Caribbean')
# <ipython-input-51-67c0de7798f9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfinal['Region'][i]='Sub-Saharan Africa'
# <ipython-input-51-67c0de7798f9>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfinal['Region'][i]='Sub-Saharan Africa'
# ...

# %%
dfinal
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1    Switzerland      Western Europe               2            7.509
# 2    Switzerland      Western Europe               4            7.494
# 3    Switzerland      Western Europe               5            7.487
# 4    Switzerland      Western Europe               6            7.480
# ..           ...                 ...             ...              ...
# 737      Namibia  Sub-Saharan Africa             113            4.574
# 738      Namibia  Sub-Saharan Africa             111            4.574
# 739      Namibia  Sub-Saharan Africa             119            4.441
# 740      Namibia  Sub-Saharan Africa             113            4.639
# 741       Gambia      Western Africa             120            4.516
#
#           GDP    Family      Life   Freedom     Trust  Generosity  Year  \
# ...

# %%
dfinal.to_csv('dataset.csv')
